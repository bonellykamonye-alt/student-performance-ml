# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("student_data.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
#  20  higher      395 non-null    str
#  21  internet    395 non-null    str
#  22  romantic    395 non-null    str
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), str(17)
# memory usage: 102.0 KB

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["G3"].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
df["G3"].value_counts().sort_index()
# Out:
# G3
# 0     38
# 4      1
# 5      7
# 6     15
# 7      9
# 8     32
# 9     28
# 10    56
# 11    47
# 12    31
# 13    31
# 14    27
# 15    33
# 16    16
# 17     6
# 18    12
# 19     5
# 20     1
# Name: count, dtype: int64

# %%
plt.hist(df["G3"],bin=21)
plt.xlabel("Final grade(G3)")
plt.ylabel("Number of students")
plt.title("Distribution of final grade")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.hist(df["G3"],bin=21)
#       2 plt.xlabel("Final grade(G3)")
#       3 plt.ylabel("Number of students")
#       4 plt.title("Distribution of final grade")
#
#     [... skipping hidden 1 frame]
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\matplotlib\pyplot.py:3661, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3636 @_copy_docstring_and_deprecators(Axes.hist)
#    3637 def hist(
#    3638     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3659     BarContainer | Polygon | list[BarContainer | Polygon],
#    3660 ]:
# -> 3661     return gca().hist(
#    3662         x,
#    3663         bins=bins,
#    3664         range=range,
#    3665         density=density,
#    3666         weights=weights,
#    3667         cumulative=cumulative,
#    3668         bottom=bottom,
#    3669         histtype=histtype,
#    3670         align=align,
#    3671         orientation=orientation,
#    3672         rwidth=rwidth,
#    3673         log=log,
#    3674         color=color,
#    3675         label=label,
#    3676         stacked=stacked,
#    3677         **({"data": data} if data is not None else {}),
#    3678         **kwargs,
#    3679     )
#
#     [... skipping hidden 2 frame]
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\matplotlib\axes\_axes.py:7676, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7674 p = patch[0]
#    7675 kwargs.update(next(style_gen))
# -> 7676 p._internal_update(kwargs)
#    7677 if lbl is not None:
#    7678     p.set_label(lbl)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\matplotlib\artist.py:1313, in Artist._internal_update(self, kwargs)
#    1306 def _internal_update(self, kwargs):
#    1307     """
#    1308     Update artist properties without prenormalizing them, but generating
#    1309     errors as if calling `set`.
#    1310
#    1311     The lack of prenormalization is to maintain backcompatibility.
#    1312     """
# -> 1313     return self._update_props(
#    1314         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1315         "{prop_name!r}")
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\matplotlib\artist.py:1271, in Artist._update_props(self, props, errfmt)
#    1269         func = getattr(self, f"set_{k}", None)
#    1270         if not callable(func):
# -> 1271             raise AttributeError(
#    1272                 errfmt.format(cls=type(self), prop_name=k),
#    1273                 name=k)
#    1274         ret.append(func(v))
#    1275 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'bin'

# %%
plt.hist(df["G3"],bins=21)
plt.xlabel("final grade (G3)")
plt.ylabel("Number of students")
plt.title("Distribution of final grades")
plt.show()

# %%
plt.scatter(df["studytime"],df["G3"])

plt.xlabel("study time")
plt.ylabel("Final grade(G3)")
plt.title("Study Time vs Final grade")
# Out:
# Text(0.5, 1.0, 'Study Time vs Final grade')

# %%
df.corr(numeric_only=True)
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# absences    0.175230  0.100285  0.024473   -0.012944  -0.062700  0.063726
# G1         -0.064081  0.205341  0.190270   -0.093040   0.160612 -0.354718
# G2         -0.143474  0.215527  0.164893   -0.153198   0.135880 -0.355896
# G3         -0.161579  0.217147  0.152457   -0.117142   0.097820 -0.360415
#
#               famrel  freetime     goout      Dalc      Walc    health  \
# age         0.053940  0.016434  0.126964  0.131125  0.117276 -0.062187
# Medu       -0.003914  0.030891  0.064094  0.019834 -0.047123 -0.046878
# Fedu       -0.001370 -0.012846  0.043105  0.002386 -0.012631  0.014742
# traveltime -0.016808 -0.017025  0.028540  0.138325  0.134116  0.007501
# studytime   0.039731 -0.143198 -0.063904 -0.196019 -0.253785 -0.075616
# failures   -0.044337  0.091987  0.124561  0.136047  0.141962  0.065827
# famrel      1.000000  0.150701  0.064568 -0.077594 -0.113397  0.094056
# freetime    0.150701  1.000000  0.285019  0.209001  0.147822  0.075733
# goout       0.064568  0.285019  1.000000  0.266994  0.420386 -0.009577
# Dalc       -0.077594  0.209001  0.266994  1.000000  0.647544  0.077180
# Walc       -0.113397  0.147822  0.420386  0.647544  1.000000  0.092476
# health      0.094056  0.075733 -0.009577  0.077180  0.092476  1.000000
# absences   -0.044354 -0.058078  0.044302  0.111908  0.136291 -0.029937
# G1          0.022168  0.012613 -0.149104 -0.094159 -0.126179 -0.073172
# G2         -0.018281 -0.013777 -0.162250 -0.064120 -0.084927 -0.097720
# G3          0.051363  0.011307 -0.132791 -0.054660 -0.051939 -0.061335
#
#             absences        G1        G2        G3
# age         0.175230 -0.064081 -0.143474 -0.161579
# Medu        0.100285  0.205341  0.215527  0.217147
# Fedu        0.024473  0.190270  0.164893  0.152457
# traveltime -0.012944 -0.093040 -0.153198 -0.117142
# studytime  -0.062700  0.160612  0.135880  0.097820
# failures    0.063726 -0.354718 -0.355896 -0.360415
# famrel     -0.044354  0.022168 -0.018281  0.051363
# freetime   -0.058078  0.012613 -0.013777  0.011307
# goout       0.044302 -0.149104 -0.162250 -0.132791
# Dalc        0.111908 -0.094159 -0.064120 -0.054660
# Walc        0.136291 -0.126179 -0.084927 -0.051939
# health     -0.029937 -0.073172 -0.097720 -0.061335
# absences    1.000000 -0.031003 -0.031777  0.034247
# G1         -0.031003  1.000000  0.852118  0.801468
# G2         -0.031777  0.852118  1.000000  0.904868
# G3          0.034247  0.801468  0.904868  1.000000

# %%
df.corr(numeric_only=True)["G3"].sort_values()
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %%
df.select_dtypes(include="object").columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.select_dtypes(include="object").columns
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv(student_data.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv(student_data.csv)
#
# NameError: name 'student_data' is not defined

# %%
df=pd.read_csv("student_data.csv")

# %%
df.select_dtypes(include="object").columns
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_20564\1196084386.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include="object").columns
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='str')

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='str')

# %%
y=df["G3"]

# %%
features = [
    "age",
    "Medu",
    "Fedu",
    "traveltime",
    "studytime",
    "failures",
    "famrel",
    "freetime",
    "goout",
    "Dalc",
    "Walc",
    "health",
    "absences",
    "school",
    "sex",
    "address",
    "famsize",
    "Pstatus",
    "Mjob",
    "Fjob",
    "reason",
    "guardian",
    "schoolsup",
    "famsup",
    "paid",
    "activities",
    "nursery",
    "higher",
    "internet",
    "romantic"
]

# %%
x=df[features]

# %%
x.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  reason  guardian  schoolsup famsup paid activities nursery  \
# 0     1  ...  course    mother        yes     no   no         no     yes
# 1     1  ...  course    father         no    yes   no         no      no
# 2     2  ...   other    mother        yes     no  yes         no     yes
# 3     1  ...    home    mother         no    yes  yes        yes     yes
# 4     1  ...    home    father         no    yes  yes         no     yes
#
#   higher internet romantic
# 0    yes       no       no
# 1    yes      yes       no
# 2    yes      yes       no
# 3    yes      yes      yes
# 4    yes       no       no
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# Name: G3, dtype: int64

# %%
x.shape
# Out:
# (395, 30)

# %%
y.shape
# Out:
# (395,)

# %%
categorical_features = [
    "school",
    "sex",
    "address",
    "famsize",
    "Pstatus",
    "Mjob",
    "Fjob",
    "reason",
    "guardian",
    "schoolsup",
    "famsup",
    "paid",
    "activities",
    "nursery",
    "higher",
    "internet",
    "romantic"
]

# %%
categorical_features = [
    "school",
    "sex",
    "address",
    "famsize",
    "Pstatus",
    "Mjob",
    "Fjob",
    "reason",
    "guardian",
    "schoolsup",
    "famsup",
    "paid",
    "activities",
    "nursery",
    "higher",
    "internet",
    "romantic"
]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_test,y_train=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print("Training data:",x_train.shape)
print("testing data:",x_test.shape)
# Out:
# Training data: (316, 30)
# testing data: (79, 30)

# %%
print("training target:",y_train.shape)
print("testing target:",y_test.shape)
# Out:
# training target: (79,)
# testing target: (316,)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ("num", "passthrough",numeric_features),
        ("cat",OneHotEncoder(handle_unknown="ignore"),categorical_features)
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 preprocessor=ColumnTransformer(
#       2     transformers=[
# ----> 3         ("num", "passthrough",numeric_features),
#       4         ("cat",OneHotEncoder(handle_unknown="ignore"),categorical_features)
#       5     ]
#       6 )
#
# NameError: name 'numeric_features' is not defined

# %%
numeric_features = [
    "age",
    "Medu",
    "Fedu",
    "traveltime",
    "studytime",
    "failures",
    "famrel",
    "freetime",
    "goout",
    "Dalc",
    "Walc",
    "health",
    "absences"
]

# %%
categorical_features = [
    "school",
    "sex",
    "address",
    "famsize",
    "Pstatus",
    "Mjob",
    "Fjob",
    "reason",
    "guardian",
    "schoolsup",
    "famsup",
    "paid",
    "activities",
    "nursery",
    "higher",
    "internet",
    "romantic"
]

# %%
print("Numerical features:", len(numeric_features))
print("Categorical features:", len(categorical_features))
# Out:
# Numerical features: 13
# Categorical features: 17

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# %%
model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", LinearRegression())
])

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\pipeline.py:649, in Pipeline.fit(self, X, y, **params)
#     643         subcontext.call_on_fit_task_begin(estimator=self, X=Xt, y=y)
#     644         last_step_params = self._get_metadata_for_step(
#     645             step_idx=len(self) - 1,
#     646             step_params=routed_params[self.steps[-1][0]],
#     647             all_params=params,
#     648         )
# --> 649         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     650         subcontext.call_on_fit_task_end(estimator=self, X=Xt, y=y)
#     651 else:
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\linear_model\_base.py:681, in LinearRegression.fit(self, X, y, sample_weight)
#     677 n_jobs_ = self.n_jobs
#     679 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 681 X, y = validate_data(
#     682     self,
#     683     X,
#     684     y,
#     685     accept_sparse=accept_sparse,
#     686     y_numeric=True,
#     687     multi_output=True,
#     688     force_writeable=True,
#     689 )
#     691 has_sw = sample_weight is not None
#     692 if has_sw:
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\utils\validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\utils\validation.py:1346, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    (...)   1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1346 check_consistent_length(X, y)
#    1348 return X, y
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\utils\validation.py:458, in check_consistent_length(*arrays)
#     456 lengths = [_num_samples(X) for X in arrays if X is not None]
#     457 if len(set(lengths)) > 1:
# --> 458     raise ValueError(
#     459         "Found input variables with inconsistent numbers of samples: %r"
#     460         % [int(l) for l in lengths]
#     461     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [316, 79]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (316, 30)
# (79,)
# (79, 30)
# (316,)

# %%
print(model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('regressor', LinearRegression())])

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\USER\OneDrive\Desktop\studentperformancedataset

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\pipeline.py:649, in Pipeline.fit(self, X, y, **params)
#     643         subcontext.call_on_fit_task_begin(estimator=self, X=Xt, y=y)
#     644         last_step_params = self._get_metadata_for_step(
#     645             step_idx=len(self) - 1,
#     646             step_params=routed_params[self.steps[-1][0]],
#     647             all_params=params,
#     648         )
# --> 649         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     650         subcontext.call_on_fit_task_end(estimator=self, X=Xt, y=y)
#     651 else:
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\linear_model\_base.py:681, in LinearRegression.fit(self, X, y, sample_weight)
#     677 n_jobs_ = self.n_jobs
#     679 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 681 X, y = validate_data(
#     682     self,
#     683     X,
#     684     y,
#     685     accept_sparse=accept_sparse,
#     686     y_numeric=True,
#     687     multi_output=True,
#     688     force_writeable=True,
#     689 )
#     691 has_sw = sample_weight is not None
#     692 if has_sw:
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\utils\validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\utils\validation.py:1346, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    (...)   1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1346 check_consistent_length(X, y)
#    1348 return X, y
#
# File ~\OneDrive\Desktop\titanicproject\.venv\Lib\site-packages\sklearn\utils\validation.py:458, in check_consistent_length(*arrays)
#     456 lengths = [_num_samples(X) for X in arrays if X is not None]
#     457 if len(set(lengths)) > 1:
# --> 458     raise ValueError(
#     459         "Found input variables with inconsistent numbers of samples: %r"
#     460         % [int(l) for l in lengths]
#     461     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [316, 79]

# %%
print("X_train:", x_train.shape)
print("y_train:", y_train.shape)
print("X_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (316, 30)
# y_train: (79,)
# X_test: (79, 30)
# y_test: (316,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print("X_train:", x_train.shape)
print("y_train:", y_train.shape)
print("X_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (316, 30)
# y_train: (316,)
# X_test: (79, 30)
# y_test: (79,)

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['age', 'Medu', 'Fedu',
#                                                    'traveltime', 'studytime',
#                                                    'failures', 'famrel',
#                                                    'freetime', 'goout', 'Dalc',
#                                                    'Walc', 'health',
#                                                    'absences']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['school', 'sex', 'address',
#                                                    'famsize', 'Pstatus', 'Mjob',
#                                                    'Fjob', 'reason', 'guardian',
#                                                    'schoolsup', 'famsup',
#                                                    'paid', 'activities',
#                                                    'nursery', 'higher',
#                                                    'internet', 'romantic'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred=model.predict(x_test)

# %%
print(y_test.values[:10])
# Out:
# [10 12  5 10  9 13 18  6  0 14]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
print("MAE:",mae)
# Out:
# MAE: 3.395260925801924

# %%
mse = mean_squared_error(y_test, y_pred)

print("MSE:", mse)
# Out:
# MSE: 17.603737398324732

# %%
r2 = r2_score(y_test, y_pred)

print("R²:", r2)
# Out:
# R²: 0.1414924741119571

# %%
print("Regression Model Performance")
print("-----------------------------")
print("MAE:", mae)
print("MSE:", mse)
print("R²:", r2)
# Out:
# Regression Model Performance
# -----------------------------
# MAE: 3.395260925801924
# MSE: 17.603737398324732
# R²: 0.1414924741119571

# %%
plt.scatter(y_test, y_pred)

plt.xlabel("Actual G3")
plt.ylabel("Predicted G3")
plt.title("Actual vs Predicted Final Grades")

plt.show()
